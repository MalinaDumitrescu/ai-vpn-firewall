# %% [markdown]
# # Benign Persona False Positive Audit
#
# This notebook demonstrates the evaluation of false-positive rates for realistic benign traffic scenarios in the clean VPN firewall pipeline.
#
# ## Why Benign Personas?
#
# - Realistic benign traffic is needed to ensure the firewall does not block normal user activity.
# - Each scenario, for example video call, gaming, or RDP, presents unique risks of being misclassified as VPN.
#
# ## Available Scenarios
#
# - List available and missing personas from `data/benign_personas/`
#
# ## PASS/MONITOR/BLOCK Rates by Persona
#
# - Placeholder: No real data yet.
#
# ## Score Distributions by Persona
#
# - Placeholder: No real data yet.
#
# ## Threshold Trade-off: Benign Blocking vs VPN Recall
#
# - Placeholder: No real data yet.
#
# ## Flow-level vs Session-level False Blocking
#
# - Placeholder: No real data yet.
#
# ## Figures to be generated
#
# - `figures/validation/benign_persona_block_rates.png`: Stacked bar chart of PASS/MONITOR/BLOCK rates.
# - `figures/validation/benign_persona_score_distributions.png`: Boxplot/violin plot of scores.
# - `figures/validation/firewall_threshold_tradeoff.png`: Line plot of threshold trade-off.
# - `figures/validation/session_vs_flow_false_block_rate.png`: Grouped bar chart of flow vs session false block rates.

# %%
# Placeholder: List available personas

import os

persona_root = "../data/benign_personas"

if os.path.exists(persona_root):
    personas = [
        d for d in os.listdir(persona_root)
        if os.path.isdir(os.path.join(persona_root, d))
    ]

    print("Available personas:", personas)

    if not personas:
        print("No persona folders found yet.")
else:
    personas = []
    print(f"Persona folder does not exist yet: {persona_root}")
# Out:
# Available personas: ['cloud_backup', 'enterprise_proxy', 'gaming_udp', 'https_browsing', 'rdp', 'streaming', 'video_call']

# %% [markdown]
# ---
#
# **Add real benign persona data under `data/benign_personas/` to enable full evaluation.**
