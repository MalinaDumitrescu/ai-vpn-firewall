# %%
import pandas as pd
from src.utils.paths import load_paths

paths = load_paths()

for name, p in {
    "vnat_features": paths.data_processed / "vnat" / "features.parquet",
    "iscx_features": paths.data_processed / "iscx" / "features.parquet",
}.items():
    df = pd.read_parquet(p)
    print("\n===", name, "===")
    print("shape:", df.shape)
    print("cols:", df.columns.tolist())
    print("label counts:", df["label"].value_counts().to_dict() if "label" in df else "NO LABEL")
    print("split counts:", df["split"].value_counts().to_dict() if "split" in df else "NO SPLIT")
# Out:
# === vnat_features ===
# shape: (33711, 92)
# ...
